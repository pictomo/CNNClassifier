# %%
# prepare data

from tensorflow.keras.datasets import cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

labels = [
    "Airplane",
    "Car",
    "Bird",
    "Cat",
    "Deer",
    "Dog",
    "Frog",
    "Horse",
    "Ship",
    "Truck",
]
label_to_index = {label: i for i, label in enumerate(labels)}

# normalize
# x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# 2025-02-01 01:12:59.488749: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-02-01 01:12:59.491360: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-02-01 01:12:59.498151: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1738339979.508762  716220 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1738339979.511949  716220 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-01 01:12:59.524413: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from tensorflow.keras import Model, Input
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, BatchNormalization
from tensorflow.keras.optimizers import Adam

def provide_model(optimizer=Adam(learning_rate=0.0005)):
    input_layer = Input(shape=(32, 32, 3))

    x = Conv2D(32, (3, 3), activation='relu', padding='same')(input_layer)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2, 2))(x)

    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2, 2))(x)

    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)

    x = Flatten()(x)
    x = Dense(64, activation='relu')(x)
    output = Dense(10, activation="softmax")(x)

    model = Model(input_layer, output)
    model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    return model
# Out:
# W0000 00:00:1738339982.468742  716220 gpu_device.cc:2344] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import numpy as np
import hashlib
import json


def hash_data(src: any) -> str:  # same as haio_hash
    return hashlib.md5(json.dumps(src, sort_keys=True).encode()).hexdigest()


data_to_label_index = {hash_data(img.tolist()): y_train[i] for i, img in enumerate(x_train)}


def provide_label(img_list) -> np.ndarray:
    return np.array([data_to_label_index[hash_data(img.tolist())] for img in img_list])

# %%
# fine-tuning

#  データの準備
data_size = 10000
x_train = x_train[:data_size]  # 最初の10,000枚だけを使う

# Active Learningの設定
initial_size = 1000  # 最初に使用するデータ数
query_size = 100  # 追加するデータ数
n_steps = 40  # ステップ数 (最大で90)

# 最初の1,000枚を使用する
initial_indices = np.arange(initial_size)
x_labeled = x_train[initial_indices]
y_labeled = np.array(provide_label(x_labeled))

# 残りの9,000枚を未使用として保持
remaining_indices = np.arange(initial_size, data_size)
x_unlabeled = x_train[remaining_indices]

# モデルを提供して初期学習
model = provide_model()
model.fit(x_labeled, y_labeled, epochs=10, verbose=1)

# Active Learningのループ
for step in range(n_steps):
    # 未使用データに対して予測を行う
    predictions = model.predict(x_unlabeled / 255.0)
    # 予測の不確実性を計算（確信度の低い順に選ぶ）
    uncertainties = np.max(predictions, axis=1)
    query_indices = np.argsort(uncertainties)[:query_size]

    # 新しく選ばれたデータをラベル付きデータに追加
    new_samples = x_unlabeled[query_indices]
    new_labels = np.array(provide_label(new_samples))

    x_labeled = np.concatenate([x_labeled, new_samples])
    y_labeled = np.concatenate([y_labeled, new_labels])

    # 未使用データから選ばれたデータを除去
    x_unlabeled = np.delete(x_unlabeled, query_indices, axis=0)

    # モデルをFine-Tuning
    model.fit(x_labeled / 255.0, y_labeled, epochs=10, batch_size=32, verbose=1)

    # テストセットでの評価
    test_loss, test_accuracy = model.evaluate(x_test / 255.0, y_test, verbose=0)
    print(f"Step {step+1}/{n_steps} - Test Accuracy: {test_accuracy:.4f}")
# Out:
# Epoch 1/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.2284 - loss: 2.3098
# Epoch 2/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6479 - loss: 1.0636
# Epoch 3/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8468 - loss: 0.5425
# Epoch 4/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9476 - loss: 0.2816
# Epoch 5/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9888 - loss: 0.1190
# Epoch 6/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9993 - loss: 0.0630
# Epoch 7/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9999 - loss: 0.0375
# Epoch 8/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0227
# Epoch 9/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0161
# Epoch 10/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0121
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Epoch 1/10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9404 - loss: 0.2532
# Epoch 2/10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9804 - loss: 0.1137
# Epoch 3/10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9963 - loss: 0.0341
# Epoch 4/10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0135
# Epoch 5/10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0069
# Epoch 6/10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0049
# Epoch 7/10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0040
# Epoch 8/10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0031
# Epoch 9/10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0028
# Epoch 10/10
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0027
# 2025-02-01 01:13:50.549644: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 122880000 exceeds 10% of free system memory.
# Step 1/40 - Test Accuracy: 0.1002
# 279/279 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Epoch 1/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9451 - loss: 0.2565
# Epoch 2/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9410 - loss: 0.1909
# Epoch 3/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9921 - loss: 0.0538
# Epoch 4/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0108
# Epoch 5/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0034
# Epoch 6/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0026
# Epoch 7/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 8/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 9/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0016
# Epoch 10/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0013
# 2025-02-01 01:13:58.218432: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 122880000 exceeds 10% of free system memory.
# Step 2/40 - Test Accuracy: 0.2103
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Epoch 1/10
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9547 - loss: 0.1601
# Epoch 2/10
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9546 - loss: 0.1509
# Epoch 3/10
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9938 - loss: 0.0429
# Epoch 4/10
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9992 - loss: 0.0111
# Epoch 5/10
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0044
# Epoch 6/10
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0026
# Epoch 7/10
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0014
# Epoch 8/10
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0011
# Epoch 9/10
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 9.7176e-04
# Epoch 10/10
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 9.2972e-04
# 2025-02-01 01:14:05.830523: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 122880000 exceeds 10% of free system memory.
# Step 3/40 - Test Accuracy: 0.4645
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Epoch 1/10
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9326 - loss: 0.2675
# Epoch 2/10
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9500 - loss: 0.1492
# Epoch 3/10
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9878 - loss: 0.0484
# Epoch 4/10
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9994 - loss: 0.0064
# Epoch 5/10
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0025
# Epoch 6/10
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 7/10
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0010
# Epoch 8/10
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 9.6342e-04
# Epoch 9/10
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 8.2087e-04
# Epoch 10/10
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 8.9939e-04
# 2025-02-01 01:14:13.856674: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 122880000 exceeds 10% of free system memory.
# Step 4/40 - Test Accuracy: 0.4705
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Epoch 1/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9366 - loss: 0.2142
# Epoch 2/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9725 - loss: 0.1044
# Epoch 3/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9908 - loss: 0.0371
# Epoch 4/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9997 - loss: 0.0055
# Epoch 5/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 6/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0014
# Epoch 7/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0010
# Epoch 8/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 8.4084e-04
# Epoch 9/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 7.8964e-04
# Epoch 10/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 6.2864e-04
# 2025-02-01 01:14:22.242046: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 122880000 exceeds 10% of free system memory.
# Step 5/40 - Test Accuracy: 0.4730
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9479 - loss: 0.1994
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9455 - loss: 0.1525
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9873 - loss: 0.0521
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9947 - loss: 0.0174
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9969 - loss: 0.0065
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0013
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0010
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 8.6421e-04
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 6.5921e-04
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 5.8873e-04
# Step 6/40 - Test Accuracy: 0.4749
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Epoch 1/10
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9506 - loss: 0.2026
# Epoch 2/10
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9361 - loss: 0.1842
# Epoch 3/10
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9754 - loss: 0.0682
# Epoch 4/10
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9991 - loss: 0.0156
# Epoch 5/10
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0032
# Epoch 6/10
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0016
# Epoch 7/10
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 8/10
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 9.3820e-04
# Epoch 9/10
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 7.8563e-04
# Epoch 10/10
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 8.0892e-04
# Step 7/40 - Test Accuracy: 0.4783
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Epoch 1/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9578 - loss: 0.1515
# Epoch 2/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9546 - loss: 0.1183
# Epoch 3/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9958 - loss: 0.0207
# Epoch 4/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9993 - loss: 0.0047
# Epoch 5/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0026
# Epoch 6/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0013
# Epoch 7/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 8.7069e-04
# Epoch 8/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 6.3190e-04
# Epoch 9/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 6.4049e-04
# Epoch 10/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 5.2906e-04
# Step 8/40 - Test Accuracy: 0.4921
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Epoch 1/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9601 - loss: 0.1616
# Epoch 2/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9743 - loss: 0.0789
# Epoch 3/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9971 - loss: 0.0138
# Epoch 4/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0028
# Epoch 5/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0011
# Epoch 6/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 8.8587e-04
# Epoch 7/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 6.6645e-04
# Epoch 8/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 5.9128e-04
# Epoch 9/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 5.7790e-04
# Epoch 10/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 4.6497e-04
# Step 9/40 - Test Accuracy: 0.4810
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Epoch 1/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9378 - loss: 0.2216
# Epoch 2/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9752 - loss: 0.0880
# Epoch 3/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9952 - loss: 0.0179
# Epoch 4/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9996 - loss: 0.0037
# Epoch 5/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 6/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 7.5451e-04
# Epoch 7/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 6.9272e-04
# Epoch 8/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 6.0825e-04
# Epoch 9/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 5.5782e-04
# Epoch 10/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 4.3401e-04
# Step 10/40 - Test Accuracy: 0.4910
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Epoch 1/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9593 - loss: 0.1586
# Epoch 2/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9722 - loss: 0.0875
# Epoch 3/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9978 - loss: 0.0132
# Epoch 4/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9968 - loss: 0.0142
# Epoch 5/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 6/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 7.4777e-04
# Epoch 7/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 7.9454e-04
# Epoch 8/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 5.5751e-04
# Epoch 9/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 5.6648e-04
# Epoch 10/10
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 4.2643e-04
# Step 11/40 - Test Accuracy: 0.4947
# 247/247 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Epoch 1/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9523 - loss: 0.1811
# Epoch 2/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9777 - loss: 0.0730
# Epoch 3/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9990 - loss: 0.0120
# Epoch 4/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0026
# Epoch 5/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0016
# Epoch 6/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0010
# Epoch 7/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 6.6900e-04
# Epoch 8/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 5.4417e-04
# Epoch 9/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 4.7364e-04
# Epoch 10/10
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 4.1831e-04
# Step 12/40 - Test Accuracy: 0.4932
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Epoch 1/10
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9622 - loss: 0.1455
# Epoch 2/10
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9718 - loss: 0.1154
# Epoch 3/10
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9925 - loss: 0.0274
# Epoch 4/10
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9980 - loss: 0.0078
# Epoch 5/10
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0021
# Epoch 6/10
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 9.5100e-04
# Epoch 7/10
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 6.6484e-04
# Epoch 8/10
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 6.1241e-04
# Epoch 9/10
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 5.0650e-04
# Epoch 10/10
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 4.0515e-04
# Step 13/40 - Test Accuracy: 0.5083
# 241/241 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Epoch 1/10
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9618 - loss: 0.2028
# Epoch 2/10
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9800 - loss: 0.0804
# Epoch 3/10
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9972 - loss: 0.0155
# Epoch 4/10
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0021
# Epoch 5/10
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 6/10
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 8.4145e-04
# Epoch 7/10
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 6.5700e-04
# Epoch 8/10
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 5.9799e-04
# Epoch 9/10
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 5.4718e-04
# Epoch 10/10
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 4.0697e-04
# Step 14/40 - Test Accuracy: 0.5144
# 238/238 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Epoch 1/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9681 - loss: 0.1162
# Epoch 2/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9745 - loss: 0.0779
# Epoch 3/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9958 - loss: 0.0193
# Epoch 4/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9894 - loss: 0.0340
# Epoch 5/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9942 - loss: 0.0141
# Epoch 6/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9996 - loss: 0.0021
# Epoch 7/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 8.8559e-04
# Epoch 8/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 6.3833e-04
# Epoch 9/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 5.5501e-04
# Epoch 10/10
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 4.7615e-04
# Step 15/40 - Test Accuracy: 0.5113
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Epoch 1/10
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9678 - loss: 0.1618
# Epoch 2/10
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9918 - loss: 0.0398
# Epoch 3/10
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9942 - loss: 0.0219
# Epoch 4/10
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9995 - loss: 0.0031
# Epoch 5/10
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 9.3333e-04
# Epoch 6/10
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 5.7116e-04
# Epoch 7/10
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 5.6838e-04
# Epoch 8/10
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 4.3923e-04
# Epoch 9/10
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 4.5341e-04
# Epoch 10/10
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 3.1302e-04
# Step 16/40 - Test Accuracy: 0.5181
# 232/232 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Epoch 1/10
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9726 - loss: 0.1327
# Epoch 2/10
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9775 - loss: 0.0646
# Epoch 3/10
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9996 - loss: 0.0101
# Epoch 4/10
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9994 - loss: 0.0030
# Epoch 5/10
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0011
# Epoch 6/10
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 7.7417e-04
# Epoch 7/10
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 6.2895e-04
# Epoch 8/10
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 4.6193e-04
# Epoch 9/10
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 4.2449e-04
# Epoch 10/10
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 3.7969e-04
# Step 17/40 - Test Accuracy: 0.5188
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Epoch 1/10
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9704 - loss: 0.1335
# Epoch 2/10
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9820 - loss: 0.0551
# Epoch 3/10
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9961 - loss: 0.0138
# Epoch 4/10
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9991 - loss: 0.0034
# Epoch 5/10
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0010
# Epoch 6/10
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 8.6705e-04
# Epoch 7/10
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 5.5794e-04
# Epoch 8/10
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 3.8614e-04
# Epoch 9/10
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 3.6598e-04
# Epoch 10/10
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 3.3533e-04
# Step 18/40 - Test Accuracy: 0.5203
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Epoch 1/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9649 - loss: 0.1533
# Epoch 2/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9849 - loss: 0.0465
# Epoch 3/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9949 - loss: 0.0147
# Epoch 4/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0032
# Epoch 5/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0010
# Epoch 6/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 6.1928e-04
# Epoch 7/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 5.1603e-04
# Epoch 8/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 3.8872e-04
# Epoch 9/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 3.4915e-04
# Epoch 10/10
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 3.9167e-04
# Step 19/40 - Test Accuracy: 0.5225
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Epoch 1/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9682 - loss: 0.1384
# Epoch 2/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9783 - loss: 0.0679
# Epoch 3/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9973 - loss: 0.0117
# Epoch 4/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9996 - loss: 0.0043
# Epoch 5/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0011
# Epoch 6/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 7.1157e-04
# Epoch 7/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 5.4754e-04
# Epoch 8/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 4.1694e-04
# Epoch 9/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 3.7598e-04
# Epoch 10/10
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 3.0797e-04
# Step 20/40 - Test Accuracy: 0.5306
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Epoch 1/10
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9636 - loss: 0.1369
# Epoch 2/10
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9797 - loss: 0.0650
# Epoch 3/10
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9960 - loss: 0.0188
# Epoch 4/10
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0035
# Epoch 5/10
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0011
# Epoch 6/10
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 8.7215e-04
# Epoch 7/10
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 5.3927e-04
# Epoch 8/10
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 4.5235e-04
# Epoch 9/10
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 4.1204e-04
# Epoch 10/10
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 3.4513e-04
# Step 21/40 - Test Accuracy: 0.5316
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Epoch 1/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9702 - loss: 0.1108
# Epoch 2/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9846 - loss: 0.0452
# Epoch 3/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9971 - loss: 0.0107
# Epoch 4/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 8.6079e-04
# Epoch 5/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 6.4991e-04
# Epoch 6/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 5.0629e-04
# Epoch 7/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 4.3094e-04
# Epoch 8/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 3.2517e-04
# Epoch 9/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 3.1485e-04
# Epoch 10/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 2.9619e-04
# Step 22/40 - Test Accuracy: 0.5329
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Epoch 1/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9628 - loss: 0.1587
# Epoch 2/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9864 - loss: 0.0408
# Epoch 3/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9970 - loss: 0.0114
# Epoch 4/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9988 - loss: 0.0072
# Epoch 5/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0022
# Epoch 6/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 5.7403e-04
# Epoch 7/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9999 - loss: 6.7520e-04
# Epoch 8/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 6.1739e-04
# Epoch 9/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9995 - loss: 0.0052
# Epoch 10/10
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 5.6904e-04
# Step 23/40 - Test Accuracy: 0.5337
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Epoch 1/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9719 - loss: 0.1071
# Epoch 2/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9788 - loss: 0.0703
# Epoch 3/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9990 - loss: 0.0064
# Epoch 4/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 5/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 7.9255e-04
# Epoch 6/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 5.0912e-04
# Epoch 7/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 4.4214e-04
# Epoch 8/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 4.3695e-04
# Epoch 9/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 5.6423e-04
# Epoch 10/10
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 2.9910e-04
# Step 24/40 - Test Accuracy: 0.5424
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Epoch 1/10
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9695 - loss: 0.1241
# Epoch 2/10
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9880 - loss: 0.0376
# Epoch 3/10
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9986 - loss: 0.0081
# Epoch 4/10
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9992 - loss: 0.0031
# Epoch 5/10
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 6/10
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 5.9933e-04
# Epoch 7/10
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 5.2653e-04
# Epoch 8/10
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 3.4295e-04
# Epoch 9/10
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 3.9785e-04
# Epoch 10/10
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 3.7348e-04
# Step 25/40 - Test Accuracy: 0.5381
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Epoch 1/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9679 - loss: 0.1345
# Epoch 2/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9885 - loss: 0.0431
# Epoch 3/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9957 - loss: 0.0128
# Epoch 4/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0022
# Epoch 5/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0010
# Epoch 6/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9999 - loss: 8.4316e-04
# Epoch 7/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 5.1700e-04
# Epoch 8/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 4.1463e-04
# Epoch 9/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 5.6525e-04
# Epoch 10/10
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 4.2019e-04
# Step 26/40 - Test Accuracy: 0.5383
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Epoch 1/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9775 - loss: 0.1003
# Epoch 2/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9809 - loss: 0.0614
# Epoch 3/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9978 - loss: 0.0111
# Epoch 4/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 5/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 8.2365e-04
# Epoch 6/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 6.6883e-04
# Epoch 7/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 5.4526e-04
# Epoch 8/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 3.1217e-04
# Epoch 9/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 2.9311e-04
# Epoch 10/10
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 2.4344e-04
# Step 27/40 - Test Accuracy: 0.5339
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Epoch 1/10
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9712 - loss: 0.1434
# Epoch 2/10
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9888 - loss: 0.0324
# Epoch 3/10
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9996 - loss: 0.0046
# Epoch 4/10
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9997 - loss: 0.0017
# Epoch 5/10
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 7.7387e-04
# Epoch 6/10
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 7.1712e-04
# Epoch 7/10
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 4.8712e-04
# Epoch 8/10
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 3.8485e-04
# Epoch 9/10
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 3.3814e-04
# Epoch 10/10
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 3.1814e-04
# Step 28/40 - Test Accuracy: 0.5513
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 1/10
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9812 - loss: 0.0699
# Epoch 2/10
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9832 - loss: 0.0618
# Epoch 3/10
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9934 - loss: 0.0173
# Epoch 4/10
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9989 - loss: 0.0037
# Epoch 5/10
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.0014
# Epoch 6/10
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 7.0327e-04
# Epoch 7/10
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 5.1528e-04
# Epoch 8/10
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 4.6328e-04
# Epoch 9/10
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 3.6874e-04
# Epoch 10/10
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 2.9628e-04
# Step 29/40 - Test Accuracy: 0.5449
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 1/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9776 - loss: 0.1085
# Epoch 2/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9821 - loss: 0.0458
# Epoch 3/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9945 - loss: 0.0204
# Epoch 4/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9998 - loss: 0.0028
# Epoch 5/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9996 - loss: 0.0015
# Epoch 6/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 4.9367e-04
# Epoch 7/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 4.4011e-04
# Epoch 8/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 3.4997e-04
# Epoch 9/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 2.9535e-04
# Epoch 10/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 2.7891e-04
# Step 30/40 - Test Accuracy: 0.5437
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 1/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9763 - loss: 0.1077
# Epoch 2/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9835 - loss: 0.0430
# Epoch 3/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9982 - loss: 0.0063
# Epoch 4/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9997 - loss: 0.0029
# Epoch 5/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9999 - loss: 8.8619e-04
# Epoch 6/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 6.2239e-04
# Epoch 7/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 4.9038e-04
# Epoch 8/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 6.7882e-04
# Epoch 9/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 3.0110e-04
# Epoch 10/10
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 2.9987e-04
# Step 31/40 - Test Accuracy: 0.5532
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 1/10
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9736 - loss: 0.1102
# Epoch 2/10
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9928 - loss: 0.0312
# Epoch 3/10
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9996 - loss: 0.0045
# Epoch 4/10
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9970 - loss: 0.0083
# Epoch 5/10
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9994 - loss: 0.0049
# Epoch 6/10
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.0011
# Epoch 7/10
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 6.8910e-04
# Epoch 8/10
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 3.8573e-04
# Epoch 9/10
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 3.2279e-04
# Epoch 10/10
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 2.9054e-04
# Step 32/40 - Test Accuracy: 0.5480
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 1/10
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9752 - loss: 0.1115
# Epoch 2/10
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9871 - loss: 0.0364
# Epoch 3/10
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9990 - loss: 0.0048
# Epoch 4/10
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.0021
# Epoch 5/10
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.0010
# Epoch 6/10
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 7.3851e-04
# Epoch 7/10
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 3.6741e-04
# Epoch 8/10
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 4.0793e-04
# Epoch 9/10
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 3.1115e-04
# Epoch 10/10
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 2.6545e-04
# Step 33/40 - Test Accuracy: 0.5514
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 1/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9765 - loss: 0.0926
# Epoch 2/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9874 - loss: 0.0370
# Epoch 3/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9971 - loss: 0.0091
# Epoch 4/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.0021
# Epoch 5/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.0014
# Epoch 6/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 5.2634e-04
# Epoch 7/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 3.6021e-04
# Epoch 8/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 5.5695e-04
# Epoch 9/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 2.6997e-04
# Epoch 10/10
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 2.1771e-04
# Step 34/40 - Test Accuracy: 0.5575
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 1/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9727 - loss: 0.1188
# Epoch 2/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9904 - loss: 0.0403
# Epoch 3/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9990 - loss: 0.0062
# Epoch 4/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.0016
# Epoch 5/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 7.8573e-04
# Epoch 6/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 5.5128e-04
# Epoch 7/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 4.5571e-04
# Epoch 8/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 3.3523e-04
# Epoch 9/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 3.2881e-04
# Epoch 10/10
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 3.1762e-04
# Step 35/40 - Test Accuracy: 0.5511
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 1/10
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9830 - loss: 0.0757
# Epoch 2/10
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9880 - loss: 0.0450
# Epoch 3/10
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9975 - loss: 0.0056
# Epoch 4/10
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9990 - loss: 0.0048
# Epoch 5/10
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 6.1173e-04
# Epoch 6/10
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 6.3479e-04
# Epoch 7/10
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 3.3914e-04
# Epoch 8/10
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 3.2152e-04
# Epoch 9/10
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 2.8823e-04
# Epoch 10/10
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 2.5461e-04
# Step 36/40 - Test Accuracy: 0.5561
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 1/10
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9733 - loss: 0.1131
# Epoch 2/10
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9887 - loss: 0.0274
# Epoch 3/10
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9981 - loss: 0.0065
# Epoch 4/10
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9995 - loss: 0.0020
# Epoch 5/10
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 9.9137e-04
# Epoch 6/10
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 4.9469e-04
# Epoch 7/10
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 3.6599e-04
# Epoch 8/10
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 3.2589e-04
# Epoch 9/10
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 3.8023e-04
# Epoch 10/10
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 2.9171e-04
# Step 37/40 - Test Accuracy: 0.5599
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 1/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9793 - loss: 0.1143
# Epoch 2/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9843 - loss: 0.0467
# Epoch 3/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9986 - loss: 0.0083
# Epoch 4/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9998 - loss: 0.0023
# Epoch 5/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 8.1705e-04
# Epoch 6/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 5.0720e-04
# Epoch 7/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 4.2804e-04
# Epoch 8/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 3.3599e-04
# Epoch 9/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 2.8049e-04
# Epoch 10/10
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 2.5205e-04
# Step 38/40 - Test Accuracy: 0.5514
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 1/10
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9817 - loss: 0.0912
# Epoch 2/10
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9876 - loss: 0.0321
# Epoch 3/10
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9974 - loss: 0.0101
# Epoch 4/10
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9990 - loss: 0.0047
# Epoch 5/10
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9981 - loss: 0.0042
# Epoch 6/10
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 7.7164e-04
# Epoch 7/10
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9990 - loss: 0.0054
# Epoch 8/10
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9995 - loss: 0.0026
# Epoch 9/10
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 6.1025e-04
# Epoch 10/10
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 3.0750e-04
# Step 39/40 - Test Accuracy: 0.5580
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 1/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9798 - loss: 0.0958
# Epoch 2/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9909 - loss: 0.0317
# Epoch 3/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9970 - loss: 0.0082
# Epoch 4/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 5/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 5.5821e-04
# Epoch 6/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 3.7855e-04
# Epoch 7/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 4.6080e-04
# Epoch 8/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 2.9287e-04
# Epoch 9/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 3.5786e-04
# Epoch 10/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 1.0000 - loss: 2.8414e-04
# Step 40/40 - Test Accuracy: 0.5628

# %%
# eval

test_loss, test_acc = model.evaluate(x_test / 255.0, y_test, verbose=2)
print("\n")
print("Test accuracy:", test_acc)
print("Test loss:", test_loss)
# Out:
# 313/313 - 1s - 3ms/step - accuracy: 0.5628 - loss: 3.7008
#
#
# Test accuracy: 0.5627999901771545
# Test loss: 3.700786828994751

# %%
# re-training

# データの準備
data_size = 10000
x_train = x_train[:data_size]  # 最初の10,000枚だけを使う

# Active Learningの設定
initial_size = 1000  # 最初に使用するデータ数
query_size = 100  # 追加するデータ数
n_steps = 40  # ステップ数 (最大で90)

# 最初の1,000枚を使用する
initial_indices = np.arange(initial_size)
x_labeled = x_train[initial_indices]
y_labeled = np.array(provide_label(x_labeled))

# 残りの9,000枚を未使用として保持
remaining_indices = np.arange(initial_size, data_size)
x_unlabeled = x_train[remaining_indices]

# モデルを提供して初期学習
model = provide_model()
model.fit(x_labeled, y_labeled, epochs=10, verbose=1)

# Active Learningのループ
for step in range(n_steps):
    # 未使用データに対して予測を行う
    predictions = model.predict(x_unlabeled / 255.0)
    # 予測の不確実性を計算（確信度の低い順に選ぶ）
    uncertainties = np.max(predictions, axis=1)
    query_indices = np.argsort(uncertainties)[:query_size]

    # 新しく選ばれたデータをラベル付きデータに追加
    new_samples = x_unlabeled[query_indices]
    new_labels = np.array(provide_label(new_samples))

    x_labeled = np.concatenate([x_labeled, new_samples])
    y_labeled = np.concatenate([y_labeled, new_labels])

    # 未使用データから選ばれたデータを除去
    x_unlabeled = np.delete(x_unlabeled, query_indices, axis=0)

    model = provide_model()
    # モデルをFine-Tuning
    model.fit(x_labeled / 255.0, y_labeled, epochs=10, batch_size=32, verbose=1)

    # テストセットでの評価
    test_loss, test_accuracy = model.evaluate(x_test / 255.0, y_test, verbose=0)
    print(f"Step {step+1}/{n_steps} - Test Accuracy: {test_accuracy:.4f}")

# %%
# eval

test_loss, test_acc = model.evaluate(x_test / 255.0, y_test, verbose=2)
print("\n")
print("Test accuracy:", test_acc)
print("Test loss:", test_loss)

# %%
# re-training

# データの準備
data_size = 10000
x_train = x_train[:data_size]  # 最初の10,000枚だけを使う

# Active Learningの設定
initial_size = 1000  # 最初に使用するデータ数
query_size = 100  # 追加するデータ数
n_steps = 40  # ステップ数 (最大で90)

# 最初の1,000枚を使用する
initial_indices = np.arange(initial_size)
x_labeled = x_train[initial_indices]
y_labeled = np.array(provide_label(x_labeled))

# 残りの9,000枚を未使用として保持
remaining_indices = np.arange(initial_size, data_size)
x_unlabeled = x_train[remaining_indices]

# モデルを提供して初期学習
model = provide_model()
model.fit(x_labeled, y_labeled, epochs=10, verbose=1)

# Active Learningのループ
for step in range(n_steps):
    # 未使用データに対して予測を行う
    predictions = model.predict(x_unlabeled / 255.0)
    # 予測の不確実性を計算（確信度の低い順に選ぶ）
    uncertainties = np.max(predictions, axis=1)
    query_indices = np.argsort(uncertainties)[:query_size]

    # 新しく選ばれたデータをラベル付きデータに追加
    new_samples = x_unlabeled[query_indices]
    new_labels = np.array(provide_label(new_samples))

    x_labeled = np.concatenate([x_labeled, new_samples])
    y_labeled = np.concatenate([y_labeled, new_labels])

    # 未使用データから選ばれたデータを除去
    x_unlabeled = np.delete(x_unlabeled, query_indices, axis=0)

    model = provide_model()
    # モデルをFine-Tuning
    model.fit(x_labeled / 255.0, y_labeled, epochs=20, batch_size=32, verbose=1)

    # テストセットでの評価
    test_loss, test_accuracy = model.evaluate(x_test / 255.0, y_test, verbose=0)
    print(f"Step {step+1}/{n_steps} - Test Accuracy: {test_accuracy:.4f}")

# %%
# eval

test_loss, test_acc = model.evaluate(x_test / 255.0, y_test, verbose=2)
print("\n")
print("Test accuracy:", test_acc)
print("Test loss:", test_loss)

# %%
# re-training
# epoch 50

# データの準備
data_size = 10000
x_train = x_train[:data_size]  # 最初の10,000枚だけを使う

# Active Learningの設定
initial_size = 1000  # 最初に使用するデータ数
query_size = 100  # 追加するデータ数
n_steps = 40  # ステップ数 (最大で90)

# 最初の1,000枚を使用する
initial_indices = np.arange(initial_size)
x_labeled = x_train[initial_indices]
y_labeled = np.array(provide_label(x_labeled))

# 残りの9,000枚を未使用として保持
remaining_indices = np.arange(initial_size, data_size)
x_unlabeled = x_train[remaining_indices]

# モデルを提供して初期学習
model = provide_model()
model.fit(x_labeled, y_labeled, epochs=10, verbose=1)

# Active Learningのループ
for step in range(n_steps):
    # 未使用データに対して予測を行う
    predictions = model.predict(x_unlabeled / 255.0)
    # 予測の不確実性を計算（確信度の低い順に選ぶ）
    uncertainties = np.max(predictions, axis=1)
    query_indices = np.argsort(uncertainties)[:query_size]

    # 新しく選ばれたデータをラベル付きデータに追加
    new_samples = x_unlabeled[query_indices]
    new_labels = np.array(provide_label(new_samples))

    x_labeled = np.concatenate([x_labeled, new_samples])
    y_labeled = np.concatenate([y_labeled, new_labels])

    # 未使用データから選ばれたデータを除去
    x_unlabeled = np.delete(x_unlabeled, query_indices, axis=0)

    model = provide_model()
    # モデルをFine-Tuning
    model.fit(x_labeled / 255.0, y_labeled, epochs=50, batch_size=32, verbose=1)

    # テストセットでの評価
    test_loss, test_accuracy = model.evaluate(x_test / 255.0, y_test, verbose=0)
    print(f"Step {step+1}/{n_steps} - Test Accuracy: {test_accuracy:.4f}")

# %%
# eval

test_loss, test_acc = model.evaluate(x_test / 255.0, y_test, verbose=2)
print("\n")
print("Test accuracy:", test_acc)
print("Test loss:", test_loss)
